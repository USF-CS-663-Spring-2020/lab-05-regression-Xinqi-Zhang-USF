# %%
import pandas as pd
df = pd.read_csv('credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
df.info()
#target: limit
#predictor: Income, Rating, Cards, Age, Education
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
# Unnamed: 0    400 non-null int64
# Income        400 non-null float64
# Limit         400 non-null int64
# Rating        400 non-null int64
# Cards         400 non-null int64
# Age           400 non-null int64
# Education     400 non-null int64
# Gender        400 non-null object
# Student       400 non-null object
# Married       400 non-null object
# Ethnicity     400 non-null object
# Balance       400 non-null int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 37.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### predictor: Income, target: limit

# %%
df.plot(kind = "scatter", x = "Income", y="Limit")

# %%
r = sns.residplot('Limit', 'Income', data=df)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(df[['Income']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_, reg.intercept_
# Out:
# (array([[51.8750206]]), array([2389.86940892]))

# %%
# y = 51.88x + 2389.87

# %% [markdown]
# ### predictor: rating, target:limit

# %%
df.plot(kind = "scatter", x = "Rating", y="Limit")

# %%
r = sns.residplot('Limit', 'Rating', data=df)

# %%
reg = LinearRegression()
reg.fit(df[['Rating']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_, reg.intercept_
# Out:
# (array([[14.87160712]]), array([-542.92822999]))

# %%
# y = 14.87x - 542.93

# %% [markdown]
# ### predictor: Cards, target: limit

# %%
df.plot(kind = "scatter", x = "Cards", y="Limit")

# %%
r = sns.residplot('Limit', 'Cards', data=df)

# %%
reg = LinearRegression()
reg.fit(df[['Cards']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_, reg.intercept_
# Out:
# (array([[17.22189457]]), array([4684.66624682]))

# %%
# y = 17.22x + 4684.67

# %% [markdown]
# ### predictor: Age, target: Limit

# %%
df.plot(kind = "scatter", x = "Age", y="Limit")

# %%
r = sns.residplot('Limit', 'Age', data=df)

# %%
reg = LinearRegression()
reg.fit(df[['Age']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_, reg.intercept_
# Out:
# (array([[13.49982568]]), array([3984.09845403]))

# %%
# y = 13.50x + 3984.10

# %% [markdown]
# ### predictor: Education, target: Limit

# %%
df.plot(kind = "scatter", x = "Education", y="Limit")

# %%
r = sns.residplot('Limit', 'Education', data=df)

# %%
reg = LinearRegression()
reg.fit(df[['Education']], df[['Limit']])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_, reg.intercept_
# Out:
# (array([[-17.39235309]]), array([4969.52714909]))

# %%
# y = -17.39x + 4969.53
